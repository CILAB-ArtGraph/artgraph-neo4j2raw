# %% [markdown]
# ## NOTEBOOK TO EXTRACT ROW FILES OF ARTGRAPH QUERYING THE DATABASE

# %%
from neo4j import GraphDatabase
import pandas as pd
import numpy as np

# %% [markdown]
# ### CONNECTION TO DATABASE

# %%
driver = GraphDatabase.driver(uri = "bolt://localhost:7687", auth = ('neo4j','neo4j'))#place here credentials

# %% [markdown]
# ### LOADING ARTEMIS DATASET

# %%
artemis = pd.read_csv('artemis_emotion_all.csv')
artemis
# Out:
#                                             painting         emotion  time
# 0           a.y.-jackson_algoma-in-november-1935.jpg             awe     1
# 1           a.y.-jackson_algoma-in-november-1935.jpg            fear     4
# 2                        a.y.-jackson_barns-1926.jpg       amusement     1
# 3                        a.y.-jackson_barns-1926.jpg             awe     2
# 4                        a.y.-jackson_barns-1926.jpg     contentment     2
# ...                                              ...             ...   ...
# 269286  zinaida-serebriakova_young-moroccan-1932.jpg       amusement     1
# 269287  zinaida-serebriakova_young-moroccan-1932.jpg             awe     1
# 269288  zinaida-serebriakova_young-moroccan-1932.jpg     contentment     1
# 269289  zinaida-serebriakova_young-moroccan-1932.jpg      excitement     1
# 269290  zinaida-serebriakova_young-moroccan-1932.jpg  something else     1
#
# [269291 rows x 3 columns]

# %% [markdown]
# ### GETTING ALL ARTWORKS

# %%
with driver.session(database='test') as session:
    ans = session.run(f"""MATCH (a:Artwork) RETURN a.name""")
    result = [record['a.name'] for record in ans]
    print(result[:10])
# Out:
# ['giuseppe-arcimboldo_portrait-of-eve-1578.jpg', 'giuseppe-arcimboldo_portrait-of-adam-1578.jpg', 'giuseppe-arcimboldo_the-vegetable-bowl.jpg', 'giuseppe-arcimboldo_vertumnus-emperor-rudolph-ii.jpg', 'giuseppe-arcimboldo_self-portrait.jpg', 'giuseppe-arcimboldo_the-dinner.jpg', 'frida-kahlo_a-few-small-nips-passionately-in-love-1935.jpg', 'frida-kahlo_coconuts-1951.jpg', 'frida-kahlo_congress-of-peoples-for-peace-1952.jpg', 'frida-kahlo_diego-and-i-1949.jpg']

# %% [markdown]
# ### INTERSECTION BETWEEN ARTGRAPH AND ARTEMIS

# %%
artemis_artworks = artemis.painting.unique().tolist()
common = set(result).intersection(set(artemis_artworks))
print(len(common))
# Out:
# 65236

# %%
artgraph_artemis = artemis[artemis.painting.isin(common)]
artgraph_artemis
# Out:
#                                             painting         emotion  time
# 188             abdullah-suriosubroto_air-terjun.jpg             awe     3
# 189             abdullah-suriosubroto_air-terjun.jpg     contentment     2
# 190          abdullah-suriosubroto_bamboo-forest.jpg             awe     2
# 191          abdullah-suriosubroto_bamboo-forest.jpg     contentment     1
# 192          abdullah-suriosubroto_bamboo-forest.jpg      excitement     2
# ...                                              ...             ...   ...
# 269286  zinaida-serebriakova_young-moroccan-1932.jpg       amusement     1
# 269287  zinaida-serebriakova_young-moroccan-1932.jpg             awe     1
# 269288  zinaida-serebriakova_young-moroccan-1932.jpg     contentment     1
# 269289  zinaida-serebriakova_young-moroccan-1932.jpg      excitement     1
# 269290  zinaida-serebriakova_young-moroccan-1932.jpg  something else     1
#
# [217131 rows x 3 columns]

# %% [markdown]
# ### CREATING EMOTION EDGES

# %%
creation_edges = artgraph_artemis.apply(lambda x: """MATCH (a:Artwork{name:\"""" + x[0] + """\"})
MERGE (e:Emotion{name:\"""" + x[1] + """\"})
CREATE (a)-[r: elicit{arousal: """ + str(x[2]) + "}]->(e)", axis = 1)
creation_edges
# Out:
# 188       MATCH (a:Artwork{name:"abdullah-suriosubroto_a...
# 189       MATCH (a:Artwork{name:"abdullah-suriosubroto_a...
# 190       MATCH (a:Artwork{name:"abdullah-suriosubroto_b...
# 191       MATCH (a:Artwork{name:"abdullah-suriosubroto_b...
# 192       MATCH (a:Artwork{name:"abdullah-suriosubroto_b...
#                                 ...
# 269286    MATCH (a:Artwork{name:"zinaida-serebriakova_yo...
# 269287    MATCH (a:Artwork{name:"zinaida-serebriakova_yo...
# 269288    MATCH (a:Artwork{name:"zinaida-serebriakova_yo...
# 269289    MATCH (a:Artwork{name:"zinaida-serebriakova_yo...
# 269290    MATCH (a:Artwork{name:"zinaida-serebriakova_yo...
# Length: 217131, dtype: object

# %% [markdown]
# ### SAVING TO FILE

# %%
save = False

# %%
if save:
    with open('emotion.cypher','w') as file:
        creation_edges.map(lambda x: print(x, file = file, end = '\n\n'))

# %% [markdown]
# ### SAVING TO DB (requires 6h)

# %%
if save:
    with driver.session(database='test') as session:
        creation_edges.map(lambda x: session.run(x))

# %% [markdown]
# ### EXTRACTING ROW FILE

# %%
with driver.session(database='test') as session:#place here the database name (not project name)
    node_types = session.run("MATCH(n) RETURN  DISTINCT labels(n)[0] as typen")#getting all node types
    node_types = [record['typen'] for record in node_types]#extracting data into a list
mapping_queries = {node.lower(): f"MATCH (n:{node}) RETURN n.name as name" for node in node_types}#generating queries for ndoe types
mapping_queries['rel'] = "MATCH (n)-[r]-(n2) RETURN DISTINCT toLower(type(r)) as rel_label"#generating queries for edge types
mapping_queries
# Out:
# {'genre': 'MATCH (n:Genre) RETURN n.name as name',
#  'style': 'MATCH (n:Style) RETURN n.name as name',
#  'artist': 'MATCH (n:Artist) RETURN n.name as name',
#  'media': 'MATCH (n:Media) RETURN n.name as name',
#  'tag': 'MATCH (n:Tag) RETURN n.name as name',
#  'artwork': 'MATCH (n:Artwork) RETURN n.name as name',
#  'movement': 'MATCH (n:Movement) RETURN n.name as name',
#  'training': 'MATCH (n:Training) RETURN n.name as name',
#  'serie': 'MATCH (n:Serie) RETURN n.name as name',
#  'subject': 'MATCH (n:Subject) RETURN n.name as name',
#  'field': 'MATCH (n:Field) RETURN n.name as name',
#  'people': 'MATCH (n:People) RETURN n.name as name',
#  'period': 'MATCH (n:Period) RETURN n.name as name',
#  'gallery': 'MATCH (n:Gallery) RETURN n.name as name',
#  'city': 'MATCH (n:City) RETURN n.name as name',
#  'country': 'MATCH (n:Country) RETURN n.name as name',
#  'emotion': 'MATCH (n:Emotion) RETURN n.name as name',
#  'rel': 'MATCH (n)-[r]-(n2) RETURN DISTINCT toLower(type(r)) as rel_label'}

# %%
node_id_mapping_queries = {node.lower(): f"MATCH (n:{node}) RETURN n.name, ID(n) as nodeId" for node in node_types}
node_id_mapping_queries
# Out:
# {'genre': 'MATCH (n:Genre) RETURN n.name, ID(n) as nodeId',
#  'style': 'MATCH (n:Style) RETURN n.name, ID(n) as nodeId',
#  'artist': 'MATCH (n:Artist) RETURN n.name, ID(n) as nodeId',
#  'media': 'MATCH (n:Media) RETURN n.name, ID(n) as nodeId',
#  'tag': 'MATCH (n:Tag) RETURN n.name, ID(n) as nodeId',
#  'artwork': 'MATCH (n:Artwork) RETURN n.name, ID(n) as nodeId',
#  'movement': 'MATCH (n:Movement) RETURN n.name, ID(n) as nodeId',
#  'training': 'MATCH (n:Training) RETURN n.name, ID(n) as nodeId',
#  'serie': 'MATCH (n:Serie) RETURN n.name, ID(n) as nodeId',
#  'subject': 'MATCH (n:Subject) RETURN n.name, ID(n) as nodeId',
#  'field': 'MATCH (n:Field) RETURN n.name, ID(n) as nodeId',
#  'people': 'MATCH (n:People) RETURN n.name, ID(n) as nodeId',
#  'period': 'MATCH (n:Period) RETURN n.name, ID(n) as nodeId',
#  'gallery': 'MATCH (n:Gallery) RETURN n.name, ID(n) as nodeId',
#  'city': 'MATCH (n:City) RETURN n.name, ID(n) as nodeId',
#  'country': 'MATCH (n:Country) RETURN n.name, ID(n) as nodeId',
#  'emotion': 'MATCH (n:Emotion) RETURN n.name, ID(n) as nodeId'}

# %%
with driver.session(database='test') as session:
    triplets = session.run("MATCH p=(a)-[r]->(b) RETURN DISTINCT labels(a)[0] as source, type(r) as relation,  labels(b)[0] as destination")
    triplets = [(t['source'], t['relation'], t['destination']) for t in triplets]
relation_queries = {str(tuple(map(lambda x:x.lower(),t))): f"MATCH (a:{t[0]})-[r:{t[1]}]->(b:{t[2]}) RETURN a.name as source_name, b.name as dest_name"
                    for t in triplets}
relation_queries
# Out:
# {"('artist', 'belongstomovement', 'movement')": 'MATCH (a:Artist)-[r:belongsToMovement]->(b:Movement) RETURN a.name as source_name, b.name as dest_name',
#  "('artist', 'hassubject', 'subject')": 'MATCH (a:Artist)-[r:hasSubject]->(b:Subject) RETURN a.name as source_name, b.name as dest_name',
#  "('artist', 'relatedtoschool', 'training')": 'MATCH (a:Artist)-[r:relatedToSchool]->(b:Training) RETURN a.name as source_name, b.name as dest_name',
#  "('artist', 'belongstofield', 'field')": 'MATCH (a:Artist)-[r:belongsToField]->(b:Field) RETURN a.name as source_name, b.name as dest_name',
#  "('artist', 'trainedby', 'artist')": 'MATCH (a:Artist)-[r:trainedBy]->(b:Artist) RETURN a.name as source_name, b.name as dest_name',
#  "('artist', 'haspatron', 'people')": 'MATCH (a:Artist)-[r:hasPatron]->(b:People) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'madeof', 'media')": 'MATCH (a:Artwork)-[r:madeOf]->(b:Media) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'about', 'tag')": 'MATCH (a:Artwork)-[r:about]->(b:Tag) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'createdby', 'artist')": 'MATCH (a:Artwork)-[r:createdBy]->(b:Artist) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'partof', 'serie')": 'MATCH (a:Artwork)-[r:partOf]->(b:Serie) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'hasstyle', 'style')": 'MATCH (a:Artwork)-[r:hasStyle]->(b:Style) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'hasgenre', 'genre')": 'MATCH (a:Artwork)-[r:hasGenre]->(b:Genre) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'locatedin', 'city')": 'MATCH (a:Artwork)-[r:locatedIn]->(b:City) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'locatedin', 'country')": 'MATCH (a:Artwork)-[r:locatedIn]->(b:Country) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'locatedin', 'gallery')": 'MATCH (a:Artwork)-[r:locatedIn]->(b:Gallery) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'elicit', 'emotion')": 'MATCH (a:Artwork)-[r:elicit]->(b:Emotion) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'hasperiod', 'period')": 'MATCH (a:Artwork)-[r:hasPeriod]->(b:Period) RETURN a.name as source_name, b.name as dest_name',
#  "('gallery', 'incountry', 'country')": 'MATCH (a:Gallery)-[r:inCountry]->(b:Country) RETURN a.name as source_name, b.name as dest_name',
#  "('gallery', 'incity', 'city')": 'MATCH (a:Gallery)-[r:inCity]->(b:City) RETURN a.name as source_name, b.name as dest_name',
#  "('city', 'incountry', 'country')": 'MATCH (a:City)-[r:inCountry]->(b:Country) RETURN a.name as source_name, b.name as dest_name'}

# %% [markdown]
# #change emotion triplet query in order to have only the best emotion
# #we need a change
# relation_queries["('artwork', 'elicits', 'emotion')"] = "MATCH (a:Artwork)-[r1:elicit]->(e1:Emotion) with a, max(r1.arousal) as max_arousal match(a)-[r2:elicit]->(e2:Emotion) where r2.arousal = max_arousal RETURN a.name as source_name, collect(e2.name)[0] as dest_name"

# %%
#here is the change
relation_queries["('artwork', 'elicits', 'emotion')"] = """
match(a:Artwork)-[r]-(e:Emotion)
with a, sum(r.arousal) as sum_arousal, e
with a, max(sum_arousal) as max_arousal
match(a)-[r2]-(e2:Emotion)
with a, sum(r2.arousal) as sum2, e2, max_arousal
where sum2 = max_arousal
return a.name as source_name, collect(e2.name)[0] as dest_name
"""

# %%
relation_queries
# Out:
# {"('artist', 'belongstomovement', 'movement')": 'MATCH (a:Artist)-[r:belongsToMovement]->(b:Movement) RETURN a.name as source_name, b.name as dest_name',
#  "('artist', 'hassubject', 'subject')": 'MATCH (a:Artist)-[r:hasSubject]->(b:Subject) RETURN a.name as source_name, b.name as dest_name',
#  "('artist', 'relatedtoschool', 'training')": 'MATCH (a:Artist)-[r:relatedToSchool]->(b:Training) RETURN a.name as source_name, b.name as dest_name',
#  "('artist', 'belongstofield', 'field')": 'MATCH (a:Artist)-[r:belongsToField]->(b:Field) RETURN a.name as source_name, b.name as dest_name',
#  "('artist', 'trainedby', 'artist')": 'MATCH (a:Artist)-[r:trainedBy]->(b:Artist) RETURN a.name as source_name, b.name as dest_name',
#  "('artist', 'haspatron', 'people')": 'MATCH (a:Artist)-[r:hasPatron]->(b:People) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'madeof', 'media')": 'MATCH (a:Artwork)-[r:madeOf]->(b:Media) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'about', 'tag')": 'MATCH (a:Artwork)-[r:about]->(b:Tag) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'createdby', 'artist')": 'MATCH (a:Artwork)-[r:createdBy]->(b:Artist) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'partof', 'serie')": 'MATCH (a:Artwork)-[r:partOf]->(b:Serie) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'hasstyle', 'style')": 'MATCH (a:Artwork)-[r:hasStyle]->(b:Style) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'hasgenre', 'genre')": 'MATCH (a:Artwork)-[r:hasGenre]->(b:Genre) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'locatedin', 'city')": 'MATCH (a:Artwork)-[r:locatedIn]->(b:City) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'locatedin', 'country')": 'MATCH (a:Artwork)-[r:locatedIn]->(b:Country) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'locatedin', 'gallery')": 'MATCH (a:Artwork)-[r:locatedIn]->(b:Gallery) RETURN a.name as source_name, b.name as dest_name',
#  "('artwork', 'elicit', 'emotion')": 'MATCH (a:Artwork)-[r1:elicit]->(e1:Emotion) with a, max(r1.arousal) as max_arousal match(a)-[r2:elicit]->(e2:Emotion) where r2.arousal = max_arousal RETURN a.name as source_name, collect(e2.name)[0] as dest_name',
#  "('artwork', 'hasperiod', 'period')": 'MATCH (a:Artwork)-[r:hasPeriod]->(b:Period) RETURN a.name as source_name, b.name as dest_name',
#  "('gallery', 'incountry', 'country')": 'MATCH (a:Gallery)-[r:inCountry]->(b:Country) RETURN a.name as source_name, b.name as dest_name',
#  "('gallery', 'incity', 'city')": 'MATCH (a:Gallery)-[r:inCity]->(b:City) RETURN a.name as source_name, b.name as dest_name',
#  "('city', 'incountry', 'country')": 'MATCH (a:City)-[r:inCountry]->(b:Country) RETURN a.name as source_name, b.name as dest_name'}

# %%
#useless
stat_queries = {
"node_labels_stats" : "MATCH (n) RETURN distinct labels(n) as node_label, count(*) as count",
"rel_labels_stats" : "MATCH (n)-[r]->(n2) RETURN distinct type(r) as rel_label, count(*) as count",
"triplet-type-list" : "MATCH (x)-[r]->(y) RETURN distinct HEAD(labels(x)) as head, type(r), head(labels(y)) as tail"
}

# %%
from raw_generation import ArtGraphWithSplit
conf = {
    "uri": "bolt://localhost:7687",
    "username": "neo4j",
    "password": 'neo4j',
    "database": "test"
}

# %%
queries = {
    'mapping': mapping_queries,
    'relations': relation_queries,
    'stats': stat_queries
}

labels = []

# %%
import os
split_paths = {
  'train': os.path.join("split", "train.csv"),
  'valid':os.path.join("split", "valid.csv"),
  'test':os.path.join("split", "test.csv")
}

# %%
artgraph = ArtGraphWithSplit(root='artgraph2bestemotions', conf=conf, queries=queries, labels=labels, split_paths=split_paths)
artgraph.build()
artgraph.write()
# Out:
# Getting mapping...
# Getting split...
# Getting relations...
#              source_name                   dest_name
# 0             john-crome  Norwich School of painters
# 1        christo-coetzee        Neo-Baroque painting
# 2               otto-dix             New Objectivity
# 3        christian-schad             New Objectivity
# 4         adolf-dietrich             New Objectivity
# ...                  ...                         ...
# 1051    viktor-vasnetsov            History painting
# 1052  elizabeth-thompson            History painting
# 1053         jan-matejko            History painting
# 1054          paul-brach    Minimalism (visual arts)
# 1055        frank-stella    Minimalism (visual arts)
#
# [1056 rows x 2 columns]
#                      source_name  \
# 0               jeremy-henderson
# 1               jeremy-henderson
# 2               jeremy-henderson
# 3      christian-ludwig-attersee
# 4      christian-ludwig-attersee
# ...                          ...
# 21049           alexander-ivanov
# 21050           alexander-ivanov
# 21051           alexander-ivanov
# 21052           alexander-ivanov
# 21053           alexander-ivanov
#
#                                                dest_name
# 0                                            2009 deaths
# 1                                        British artists
# 2                                            1952 births
# 3                              21st-century male artists
# 4                              20th-century male artists
# ...                                                  ...
# 21049  Awarded with a large gold medal of the Academy...
# 21050                    Imperial Academy of Arts alumni
# 21051                      19th-century Russian painters
# 21052                       People from Saint Petersburg
# 21053            Members of the Imperial Academy of Arts
#
# [21054 rows x 2 columns]
#                     source_name                  dest_name
# 0                  lasar-segall   Prussian Academy of Arts
# 1                 alex-colville   Mount Allison University
# 2                   alice-baber         Indiana University
# 3               dan-christensen         Indiana University
# 4        julio-romero-de-torres       Rafael Romero Barros
# ..                          ...                        ...
# 493            richard-hamilton  University College London
# 494  alexandre-jacques-chantron              Salon (Paris)
# 495                   paul-klee        List of art schools
# 496              alfred-krupa-0        List of art schools
# 497      thomas-francis-dicksee      Henry Perronet Briggs
#
# [498 rows x 2 columns]
#              source_name         dest_name
# 0      utagawa-kuniyoshi           ukiyo-e
# 1    tsukioka-yoshitoshi           ukiyo-e
# 2     katsushika-hokusai           ukiyo-e
# 3         elenore-abbott     scenic design
# 4           marcel-janco     scenic design
# ..                   ...               ...
# 982          erin-hanson  contemporary art
# 983     susan-rothenberg  contemporary art
# 984        dumitru-gorzo  contemporary art
# 985            alaa-awad        public art
# 986        dumitru-gorzo        public art
#
# [987 rows x 2 columns]
#                   source_name                   dest_name
# 0                   giorgione            giovanni-bellini
# 1           sandro-botticelli               filippo-lippi
# 2            anthony-van-dyck           peter-paul-rubens
# 3                jan-van-eyck               robert-campin
# 4             pietro-perugino        andrea-del-verrochio
# 5            vincent-van-gogh                 anton-mauve
# 6               henri-matisse  william-adolphe-bouguereau
# 7               henri-matisse              gustave-moreau
# 8           peter-paul-rubens              adam-van-noort
# 9           peter-paul-rubens               otto-van-veen
# 10          peter-paul-rubens            tobias-verhaecht
# 11       zinaida-serebriakova                  ilya-repin
# 12              alfred-sisley              charles-gleyre
# 13                  jan-steen          adriaen-van-ostade
# 14  pierre-puvis-de-chavannes              thomas-couture
# 15             andrea-solario        antonello-da-messina
# 16             giorgio-vasari            andrea-del-sarto
# 17                  gwen-john      james-mcneill-whistler
# 18                lee-krasner                hans-hofmann
# 19                jimmy-ernst                   max-ernst
# 20       janos-mattis-teutsch                 franz-stuck
# 21                  eva-hesse                josef-albers
# 22           robert-goodnough                hans-hofmann
# 23              john-trumbull               benjamin-west
# 24            nicolae-vermont                theodor-aman
# 25          roberto-aizenberg               antonio-berni
# 26             albert-marquet              gustave-moreau
# 27        nicholas-krushenick                hans-hofmann
# 28                 zao-wou-ki                lin-fengmian
# 29               pinturicchio             pietro-perugino
# 30            francisco-oller             gustave-courbet
# 31            francisco-oller              thomas-couture
# 32             nicolas-carone                hans-hofmann
# 33        henry-ossawa-tanner               thomas-eakins
# 34        henry-ossawa-tanner           benjamin-constant
# 35               william-hart       jules-joseph-lefebvre
# 36               henri-gervex           alexandre-cabanel
# 37           mikhail-larionov               isaac-levitan
# 38           mikhail-larionov              valentin-serov
# 39                anna-ancher   pierre-puvis-de-chavannes
# 40           hyacinthe-rigaud             charles-le-brun
# 41    emanuel-gottlieb-leutze                karl-lessing
# 42                  hans-gude           andreas-achenbach
# 43  sophie-gengembre-anderson          charles-de-steuben
# 44          theodore-robinson               carolus-duran
# 45            filippino-lippi               filippo-lippi
# 46              pompeo-batoni            sebastiano-conca
#            source_name                        dest_name
# 0    bernard-van-orley              Margaret of Austria
# 1           caravaggio               Alof de Wignacourt
# 2       pieter-wenning                    Ernest Lezard
# 3        henry-raeburn  George IV of the United Kingdom
# 4        albert-tucker             John and Sunday Reed
# ..                 ...                              ...
# 119    rembrandt-peale                George Washington
# 120          canaletto         Joseph Smith (1682–1770)
# 121      henri-matisse                        Etta Cone
# 122      benjamin-west         William Henry (delegate)
# 123       claude-monet               Georges Clemenceau
#
# [124 rows x 2 columns]
#                                              source_name       dest_name
# 0      marc-chagall_abraham-prostrated-himself-front-...             oil
# 1                john-william-godward_yes-or-no-1893.jpg             oil
# 2            william-merritt-chase_pulling-for-shore.jpg             oil
# 3      cima-da-conegliano_doubting-thomas-with-st-mag...             oil
# 4           jan-siberechts_a-pastoral-landscape-1684.jpg             oil
# ...                                                  ...             ...
# 83819              chris-ofili_pimpin-aint-easy-1997.jpg        map pins
# 83820              chris-ofili_pimpin-aint-easy-1997.jpg   elephant dung
# 83821              chris-ofili_pimpin-aint-easy-1997.jpg       polyester
# 83822          chris-ofili_the-caged-birds-song-2017.jpg        tapestry
# 83823          paul-gauguin_change-of-residence-1899.jpg  japanese paper
#
# [83824 rows x 2 columns]
#                                               source_name  \
# 0            boris-kustodiev_vegetables-merchant-1920.jpg
# 1       andre-derain_the-still-life-with-pumpkin-1939.jpg
# 2       zinaida-serebriakova_still-life-with-a-basket-...
# 3       gustave-courbet_still-life-with-pears-and-appl...
# 4       frans-snyders_still-life-with-fruit-basket-and...
# ...                                                   ...
# 342977      john-flaxman_william-pitt-earl-of-chatham.jpg
# 342978                       maria-fortuny_hollyhocks.jpg
# 342979                    james-rosenquist_disks-1963.jpg
# 342980             steve-kaufman_spiderman-iv-red-sky.jpg
# 342981                   beauford-delaney_jennie-1943.jpg
#
#                     dest_name
# 0       fruits-and-vegetables
# 1       fruits-and-vegetables
# 2       fruits-and-vegetables
# 3       fruits-and-vegetables
# 4       fruits-and-vegetables
# ...                       ...
# 342977                  Medal
# 342978       Rosa wichuraiana
# 342979                   Hood
# 342980         Fantastic four
# 342981                Selling
#
# [342982 rows x 2 columns]
#                                               source_name         dest_name
# 0                        antonio-lopez_dead-girl-1957.jpg     antonio-lopez
# 1                       antonio-lopez_artists-working.jpg     antonio-lopez
# 2             antonio-lopez_sinforoso-and-josefa-1955.jpg     antonio-lopez
# 3                anatoli-papian_portrait-of-anna-1983.jpg    anatoli-papian
# 4           hans-richter_portrait-of-dora-rukser-1927.jpg      hans-richter
# ...                                                   ...               ...
# 116470   alexander-ivanov_portrait-of-vittoria-marini.jpg  alexander-ivanov
# 116471                   alexander-ivanov_olive-trees.jpg  alexander-ivanov
# 116472             alexander-ivanov_annunciation-1824.jpg  alexander-ivanov
# 116473  alexander-ivanov_on-the-shore-of-the-bay-of-na...  alexander-ivanov
# 116474  alexander-ivanov_joseph-interpreting-dreams-to...  alexander-ivanov
#
# [116475 rows x 2 columns]
#                                             source_name  \
# 0     albrecht-durer_treatise-on-measurement-1525-1.jpg
# 1       albrecht-durer_treatise-on-measurement-1525.jpg
# 2     albrecht-durer_treatise-on-measurement-1525-0.jpg
# 3     ivan-bilibin_sketch-for-the-opera-the-golden-c...
# 4     ivan-bilibin_sketch-for-the-opera-the-golden-c...
# ...                                                 ...
# 8317  alexandre-benois_flora-pool-in-versailles-1906...
# 8318                    alexandre-benois_versailles.jpg
# 8319         alexandre-benois_versailles-alley-1906.jpg
# 8320     alexandre-benois_versailles-water-parterre.jpg
# 8321  alexandre-benois_versailles-mirror-at-trianon.jpg
#
#                                               dest_name
# 0     Instruction in measurement with compass and ru...
# 1     Instruction in measurement with compass and ru...
# 2     Instruction in measurement with compass and ru...
# 3                                    The Golden Cockere
# 4                                    The Golden Cockere
# ...                                                 ...
# 8317                                         Versailles
# 8318                                         Versailles
# 8319                                         Versailles
# 8320                                         Versailles
# 8321                                         Versailles
#
# [8322 rows x 2 columns]
#                                               source_name        dest_name
# 0       zinaida-serebriakova_menton-beach-with-umbrell...         art deco
# 1                                    erte_autumn-song.jpg         art deco
# 2                                       erte_feathers.jpg         art deco
# 3                                john-austen_hamlet-6.jpg         art deco
# 4                      zinaida-serebriakova_bath-1926.jpg         art deco
# ...                                                   ...              ...
# 116470       theodor-severin-kittelsen_noekken-1904-1.jpg  neo-romanticism
# 116471  theodor-severin-kittelsen_kveld-paa-soletunet-...  neo-romanticism
# 116472  theodor-severin-kittelsen_brudeferden-i-hardan...  neo-romanticism
# 116473           stanley-spencer_sorting-laundry-1927.jpg  neo-romanticism
# 116474           stanley-spencer_apple-gatherers-1913.jpg  neo-romanticism
#
# [116475 rows x 2 columns]
#                                               source_name           dest_name
# 0       paul-jacoulet_le-chant-des-vagues-ponape-est-c...  nude painting (nu)
# 1                               bela-czobel_muse-1930.jpg  nude painting (nu)
# 2                otto-mueller_zwei-zigeunerinnen-1923.jpg  nude painting (nu)
# 3                         eliseu-visconti_nu-feminino.jpg  nude painting (nu)
# 4              william-merritt-chase_back-of-a-nude-1.jpg  nude painting (nu)
# ...                                                   ...                 ...
# 116470          robert-spencer_the-crowding-city-1925.jpg           cityscape
# 116471  giovanni-battista-piranesi_the-roman-antiquiti...           cityscape
# 116472                           william-turner_hafod.jpg           cityscape
# 116473             gustave-loiseau_the-road-to-dieppe.jpg           cityscape
# 116474          lajos-tihanyi_street-in-trencs-n-1912.jpg           cityscape
#
# [116475 rows x 2 columns]
#                                              source_name      dest_name
# 0                 wayne-thiebaud_sunset-streets-1985.jpg  San Francisco
# 1                richard-diebenkorn_woman-in-profile.jpg  San Francisco
# 2                  richard-diebenkorn_berkeley-no-23.jpg  San Francisco
# 3                richard-diebenkorn_ocean-park-no-54.jpg  San Francisco
# 4                       clyfford-still_untitled-1948.jpg  San Francisco
# ...                                                  ...            ...
# 19527       hyacinthe-rigaud_louis-de-france-dauphin.jpg     Versailles
# 19528  charles-andre-van-loo-carle-van-loo_marquise-d...     Versailles
# 19529  charles-andre-van-loo-carle-van-loo_marie-lesz...     Versailles
# 19530  louise-elisabeth-vigee-le-brun_marie-antoinett...     Versailles
# 19531        franz-xaver-winterhalter_leopold-i-1840.jpg     Versailles
#
# [19532 rows x 2 columns]
#                                              source_name   dest_name
# 0           berthe-morisot_julie-manet-and-her-nurse.jpg     Denmark
# 1      gustave-courbet_three-english-girls-at-a-windo...     Denmark
# 2             camille-pissarro_rue-saint-lazare-1897.jpg     Denmark
# 3      christen-kobke_the-garden-steps-leading-to-the...     Denmark
# 4                  christen-kobke_self-portrait-1833.jpg     Denmark
# ...                                                  ...         ...
# 19483          isaac-levitan_trunk-of-burgeoning-oak.jpg  Kyrgyzstan
# 19484      isaac-levitan_landscape-with-an-isba-1899.jpg  Uzbekistan
# 19485             nicholas-roerich_prince-knyaz-1916.jpg  Uzbekistan
# 19486                 isaac-levitan_forest-sunny-day.jpg  Uzbekistan
# 19487  anthony-van-dyck_portrait-of-maria-louisa-de-t...  Luxembourg
#
# [19488 rows x 2 columns]
#                                              source_name  \
# 0      jean-auguste-dominique-ingres_view-of-the-acro...
# 1      ford-madox-brown_john-wycliffe-reading-his-tra...
# 2                          joshua-reynolds_brown-boy.jpg
# 3          john-singer-sargent_mrs-ernest-hills-1909.jpg
# 4                       allan-ramsay_queen-charlotte.jpg
# ...                                                  ...
# 19499  amedeo-modigliani_jeanne-hebuterne-in-a-yellow...
# 19500          wassily-kandinsky_not_detected_189366.jpg
# 19501                 jackson-pollock_blue-moby-dick.jpg
# 19502            chaim-soutine_little-girl-with-doll.jpg
# 19503  jan-brueghel-the-elder_monkeys-feasting-singer...
#
#                             dest_name
# 0                 Montauban Cathedral
# 1      Bradford Museums and Galleries
# 2      Bradford Museums and Galleries
# 3      Bradford Museums and Galleries
# 4                      Blickling Hall
# ...                               ...
# 19499             Ohara Museum of Art
# 19500             Ohara Museum of Art
# 19501             Ohara Museum of Art
# 19502       Hillman Family Foundation
# 19503       Rubens House (Rubenshuis)
#
# [19504 rows x 2 columns]
#                                              source_name       dest_name
# 0       aladar-korosfoi-kriesch_pupppet-theatre-1907.jpg         sadness
# 1      zinaida-serebriakova_yevgeny-lanceray-in-a-sha...       amusement
# 2            zinaida-serebriakova_self-portrait-1930.jpg  something else
# 3      zinaida-serebriakova_princess-irina-yusupov-19...  something else
# 4      zinaida-serebriakova_portrait-of-the-composer-...            fear
# ...                                                  ...             ...
# 65231               jean-degottex_chattigraphie-1974.jpg  something else
# 65232                   gene-davis_untitled-150-1971.jpg  something else
# 65233                    friedel-dzubas_durango-1968.jpg  something else
# 65234            ellsworth-kelly_white-on-white-1951.jpg  something else
# 65235                    agnes-martin_this-rain-1960.jpg  something else
#
# [65236 rows x 2 columns]
#                                             source_name             dest_name
# 0     paul-gauguin_still-life-with-red-mullet-and-ju...           Early works
# 1                    paul-gauguin_rouen-suburb-1884.jpg           Early works
# 2     paul-gauguin_interior-of-the-painter-s-house-r...           Early works
# 3            paul-gauguin_women-bathing-dieppe-1885.jpg           Early works
# 4         paul-gauguin_still-life-with-oysters-1876.jpg           Early works
# ...                                                 ...                   ...
# 5743        luca-giordano_the-triumph-of-david-1682.jpg  Florence (1682-1692)
# 5744  luca-giordano_the-martyrdom-of-saint-januarius...  Florence (1682-1692)
# 5745      luca-giordano_young-bacchus-sleeping-1683.jpg  Florence (1682-1692)
# 5746              luca-giordano_the-visitation-1683.jpg  Florence (1682-1692)
# 5747      luca-giordano_marriage-of-the-virgin-1688.jpg  Florence (1682-1692)
#
# [5748 rows x 2 columns]
#                                   source_name    dest_name
# 0                                 Ordrupgaard      Denmark
# 1                              Skagens Museum      Denmark
# 2                      Ny Carlsberg Glyptotek      Denmark
# 3                       Randers Museum of Art      Denmark
# 4           Natural History Museum of Denmark      Denmark
# ...                                       ...          ...
# 1100             P. and N. de Boer Foundation  Netherlands
# 1101                         Groninger Museum  Netherlands
# 1102  State museum of fine arts of Kyrgyzstan   Kyrgyzstan
# 1103             Museum of Arts of Uzbekistan   Uzbekistan
# 1104                       Grand Ducal Palace   Luxembourg
#
# [1105 rows x 2 columns]
# INFO:root:Saving on the disk all nodes
# INFO:root:Saving on the disk node mapping genre in path artgraph2bestemotions\mapping\genre_entidx2name.csv
# INFO:root:Saving on the disk node mapping style in path artgraph2bestemotions\mapping\style_entidx2name.csv
# INFO:root:Saving on the disk node mapping artist in path artgraph2bestemotions\mapping\artist_entidx2name.csv
# INFO:root:Saving on the disk node mapping media in path artgraph2bestemotions\mapping\media_entidx2name.csv
# INFO:root:Saving on the disk node mapping tag in path artgraph2bestemotions\mapping\tag_entidx2name.csv
# INFO:root:Saving on the disk node mapping artwork in path artgraph2bestemotions\mapping\artwork_entidx2name.csv
#                                       source_name      dest_name
# 0                          George Krevsky Gallery  San Francisco
# 1                                 Legion of Honor  San Francisco
# 2              Fine Arts Museums of San Francisco  San Francisco
# 3     San Francisco Museum of Modern Art (SFMOMA)  San Francisco
# 4                          Parma National Gallery          Parma
# ...                                           ...            ...
# 1104                           San Pietro Martire         Murano
# 1105        Novosibirsk State Museum of Fine Arts    Novosibirsk
# 1106           National Gallery of Victoria (NGV)      Melbourne
# 1107                    Tver Regional Art Gallery           Tver
# 1108                        Château de Versailles     Versailles
#
# [1109 rows x 2 columns]
#          source_name    dest_name
# 0             Skagen      Denmark
# 1          Humlebaek      Denmark
# 2         Copenhagen      Denmark
# 3            Randers      Denmark
# 4          Blackburn           UK
# ..               ...          ...
# 603          Haarlem  Netherlands
# 604          Otterlo  Netherlands
# 605          Bishkek   Kyrgyzstan
# 606         Tashkent   Uzbekistan
# 607  Luxembourg City   Luxembourg
#
# [608 rows x 2 columns]
# Getting labels
# Writing mapping...
# INFO:root:Saving on the disk node mapping movement in path artgraph2bestemotions\mapping\movement_entidx2name.csv
# INFO:root:Saving on the disk node mapping training in path artgraph2bestemotions\mapping\training_entidx2name.csv
# INFO:root:Saving on the disk node mapping serie in path artgraph2bestemotions\mapping\serie_entidx2name.csv
# INFO:root:Saving on the disk node mapping subject in path artgraph2bestemotions\mapping\subject_entidx2name.csv
# INFO:root:Saving on the disk node mapping field in path artgraph2bestemotions\mapping\field_entidx2name.csv
# INFO:root:Saving on the disk node mapping people in path artgraph2bestemotions\mapping\people_entidx2name.csv
# INFO:root:Saving on the disk node mapping period in path artgraph2bestemotions\mapping\period_entidx2name.csv
# INFO:root:Saving on the disk node mapping gallery in path artgraph2bestemotions\mapping\gallery_entidx2name.csv
# INFO:root:Saving on the disk node mapping city in path artgraph2bestemotions\mapping\city_entidx2name.csv
# INFO:root:Saving on the disk node mapping country in path artgraph2bestemotions\mapping\country_entidx2name.csv
# INFO:root:Saving on the disk node mapping emotion in path artgraph2bestemotions\mapping\emotion_entidx2name.csv
# INFO:root:Saving on the disk node mapping rel in path artgraph2bestemotions\mapping\rel_entidx2name.csv
# INFO:root:Saving on the disk all relations
# INFO:root:Saving on the disk relation belongstomovement in path artgraph2bestemotions\raw\relations\artist___belongstomovement___movement
# INFO:root:Saving on the disk relation hassubject in path artgraph2bestemotions\raw\relations\artist___hassubject___subject
# INFO:root:Saving on the disk relation relatedtoschool in path artgraph2bestemotions\raw\relations\artist___relatedtoschool___training
# INFO:root:Saving on the disk relation belongstofield in path artgraph2bestemotions\raw\relations\artist___belongstofield___field
# INFO:root:Saving on the disk relation trainedby in path artgraph2bestemotions\raw\relations\artist___trainedby___artist
# INFO:root:Saving on the disk relation haspatron in path artgraph2bestemotions\raw\relations\artist___haspatron___people
# INFO:root:Saving on the disk relation madeof in path artgraph2bestemotions\raw\relations\artwork___madeof___media
# INFO:root:Saving on the disk relation about in path artgraph2bestemotions\raw\relations\artwork___about___tag
# INFO:root:Saving on the disk relation createdby in path artgraph2bestemotions\raw\relations\artwork___createdby___artist
# INFO:root:Saving on the disk relation partof in path artgraph2bestemotions\raw\relations\artwork___partof___serie
# INFO:root:Saving on the disk relation hasstyle in path artgraph2bestemotions\raw\relations\artwork___hasstyle___style
# INFO:root:Saving on the disk relation hasgenre in path artgraph2bestemotions\raw\relations\artwork___hasgenre___genre
# INFO:root:Saving on the disk relation locatedin in path artgraph2bestemotions\raw\relations\artwork___locatedin___city
# INFO:root:Saving on the disk relation locatedin in path artgraph2bestemotions\raw\relations\artwork___locatedin___country
# INFO:root:Saving on the disk relation locatedin in path artgraph2bestemotions\raw\relations\artwork___locatedin___gallery
# INFO:root:Saving on the disk relation elicit in path artgraph2bestemotions\raw\relations\artwork___elicit___emotion
# INFO:root:Saving on the disk relation hasperiod in path artgraph2bestemotions\raw\relations\artwork___hasperiod___period
# INFO:root:Saving on the disk relation incountry in path artgraph2bestemotions\raw\relations\gallery___incountry___country
# INFO:root:Saving on the disk relation incity in path artgraph2bestemotions\raw\relations\gallery___incity___city
# INFO:root:Saving on the disk relation incountry in path artgraph2bestemotions\raw\relations\city___incountry___country
# INFO:root:Saving on the disk node mapping train in path artgraph2bestemotions\raw\split\artwork\train.csv
# INFO:root:Saving on the disk node mapping test in path artgraph2bestemotions\raw\split\artwork\test.csv
# Writing labels...
# Writing info...
# Writing split...
# INFO:root:Saving on the disk node mapping valid in path artgraph2bestemotions\raw\split\artwork\valid.csv
